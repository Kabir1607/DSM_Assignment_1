# %% [markdown]
# # Overview:

# %% [markdown]
# I have had a look at the orignal website that were were told to use (https://www.gdacs.org/Alerts/default.aspx). Unfortunately, it is extremely buggy, works at some points and not at others.
# Thus, the other two websites:
# https://reliefweb.int/
# https://www.emdat.be/
# are used instead.
#
# https://reliefweb.int/ --> Gives more text data, such as reports and descriptions of the disasters etc. This can be useful for sentiment analysis.
# https://www.emdat.be/ --> Gives more tabular data, such as the number of people affected, the number of deaths, the number of injuries etc. This can be useful for analysis of the severity of the disasters. Also, from what I looked into, genereally considered trustable within the community.
#
# Although both claim no legal responsbility for truth and validation of claims, so make that what you will.
#
# As and when needed, I can also look for other websites and reports to use based on the specific incidents (disasters)

# %% [markdown]
# # Task 1

# %% [markdown]
# The plan is to first connect to and scrape from https://reliefweb.int/
# https://www.emdat.be/
#
# to get the data of natural disasters and pick one that has the most data, fits the criteria of the assignment and is researchable with other articles and data.
#
# For this, I need to validate that the diaster mentioned in https://www.emdat.be/ is the same one as in https://reliefweb.int/.

# %%
# Get the data for natural disasters from https://www.emdat.be/ and https://reliefweb.int/ that is no more than 10 years old (globally) (to ensure truth as the website says data from before then is unreliable).
# Just look at what data is avaliable in both for now. Then, based on what I get, decide what I pick to explore further. 
# If I do not do this, I may end up in a situation where I pick a diaster with not much or even conflicting data avaliable. 
# Save the data in a csv file for https://www.emdat.be/ in the "Tabular_Data" folder
# Save the text data with what diaster it is for from https://reliefweb.int/ in a directory in this folder called "Text_Data"
# Also get data from https://data.humdata.org. 
# Do this for the following types of diasters: Earthquakes, Tsunamis, Floods, Cyclones, Volcanoes, Droughts, or Forest Fires
# Do this via API calls to the websites

# %%
# !pip install requests pandas openpyxl playwright
# !playwright install chromium

# %%
# !python multi_source_scraper.py
